# %%
# Computations
import numpy as np
import pandas as pd

# preprocessing
from sklearn import preprocessing

# sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import plot_confusion_matrix, roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score, KFold
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier

# Progress Bar
import progressbar

# Visualisation libraries
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Polygon
import matplotlib.gridspec as gridspec

# sns setting
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":14,"axes.labelsize":12})
sns.set_style("whitegrid")

# plt setting
plt.style.use('seaborn-whitegrid')
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['text.color'] = 'k'
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/5/51/IBM_logo.svg' width='450' align="center"/>

# %% [markdown]
# # IBM HR Analytics Employee Attrition & Performance
#
# In this study, we analyze HR data available from   [kaggle.com](https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset)
#
# This data is **fictional** and it is created by IBM data scientists.
#
# Categorical Parameters:
#
# |                           |       1       |    2    |     3     |      4      |    5   |
# |:-------------------------:|:-------------:|:-------:|:---------:|:-----------:|:------:|
# |         Education         | Below College | College |  Bachelor |    Master   | Doctor |
# |  Environment Satisfaction |      Low      |  Medium |    High   |  Very High  |        |
# |      Job Involvement      |      Low      |  Medium |    High   |  Very High  |        |
# |      Job Satisfaction     |      Low      |  Medium |    High   |  Very High  |        |
# |     Performance Rating    |      Low      |   Good  | Excellent | Outstanding |        |
# | Relationship Satisfaction |      Low      |  Medium |    High   |  Very High  |        |
# |      WorkLife Balance     |      Bad      |   Good  |   Better  |     Best    |        |

# %% [markdown]
# #### Table of contents
#
# * [Modeling](#Modeling)
#     * [Correlation](#Correlation)
#     * [Training and testing sets](#Training-and-testing-sets)
#     * [Classifiers](#Classifiers)
#     * [Final Model](#Final-Model)
#     * [Confusion Matrix](#Confusion-Matrix)

# %% [markdown]
# ### Loading the Data

# %%
Data = pd.read_excel('Data/WA_Fn-UseC_-HR-Employee-Attrition.xlsx')
Data.head().style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_4f9c330a_8983_11ea_9824_50e08586bf81" ><thead>    <tr>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >Attrition</th>        <th class="col_heading level0 col2" >BusinessTravel</th>        <th class="col_heading level0 col3" >DailyRate</th>        <th class="col_heading level0 col4" >Department</th>        <th class="col_heading level0 col5" >DistanceFromHome</th>        <th class="col_heading level0 col6" >Education</th>        <th class="col_heading level0 col7" >EducationField</th>        <th class="col_heading level0 col8" >EmployeeCount</th>        <th class="col_heading level0 col9" >EmployeeNumber</th>        <th class="col_heading level0 col10" >EnvironmentSatisfaction</th>        <th class="col_heading level0 col11" >Gender</th>        <th class="col_heading level0 col12" >HourlyRate</th>        <th class="col_heading level0 col13" >JobInvolvement</th>        <th class="col_heading level0 col14" >JobLevel</th>        <th class="col_heading level0 col15" >JobRole</th>        <th class="col_heading level0 col16" >JobSatisfaction</th>        <th class="col_heading level0 col17" >MaritalStatus</th>        <th class="col_heading level0 col18" >MonthlyIncome</th>        <th class="col_heading level0 col19" >MonthlyRate</th>        <th class="col_heading level0 col20" >NumCompaniesWorked</th>        <th class="col_heading level0 col21" >Over18</th>        <th class="col_heading level0 col22" >OverTime</th>        <th class="col_heading level0 col23" >PercentSalaryHike</th>        <th class="col_heading level0 col24" >PerformanceRating</th>        <th class="col_heading level0 col25" >RelationshipSatisfaction</th>        <th class="col_heading level0 col26" >StandardHours</th>        <th class="col_heading level0 col27" >StockOptionLevel</th>        <th class="col_heading level0 col28" >TotalWorkingYears</th>        <th class="col_heading level0 col29" >TrainingTimesLastYear</th>        <th class="col_heading level0 col30" >WorkLifeBalance</th>        <th class="col_heading level0 col31" >YearsAtCompany</th>        <th class="col_heading level0 col32" >YearsInCurrentRole</th>        <th class="col_heading level0 col33" >YearsSinceLastPromotion</th>        <th class="col_heading level0 col34" >YearsWithCurrManager</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col0" class="data row0 col0" >41</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col1" class="data row0 col1" >Yes</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col2" class="data row0 col2" >Travel_Rarely</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col3" class="data row0 col3" >1102</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col4" class="data row0 col4" >Sales</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col6" class="data row0 col6" >2</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col7" class="data row0 col7" >Life Sciences</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col8" class="data row0 col8" >1</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col9" class="data row0 col9" >1</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col11" class="data row0 col11" >Female</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col12" class="data row0 col12" >94</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col13" class="data row0 col13" >3</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col14" class="data row0 col14" >2</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col15" class="data row0 col15" >Sales Executive</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col16" class="data row0 col16" >4</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col17" class="data row0 col17" >Single</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col18" class="data row0 col18" >5993</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col19" class="data row0 col19" >19479</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col20" class="data row0 col20" >8</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col21" class="data row0 col21" >Y</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col22" class="data row0 col22" >Yes</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col23" class="data row0 col23" >11</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col24" class="data row0 col24" >3</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col25" class="data row0 col25" >1</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col26" class="data row0 col26" >80</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col27" class="data row0 col27" >0</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col28" class="data row0 col28" >8</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col29" class="data row0 col29" >0</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col30" class="data row0 col30" >1</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col31" class="data row0 col31" >6</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col32" class="data row0 col32" >4</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col33" class="data row0 col33" >0</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row0_col34" class="data row0 col34" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col0" class="data row1 col0" >49</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col1" class="data row1 col1" >No</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col2" class="data row1 col2" >Travel_Frequently</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col3" class="data row1 col3" >279</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col4" class="data row1 col4" >Research & Development</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col5" class="data row1 col5" >8</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col7" class="data row1 col7" >Life Sciences</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col8" class="data row1 col8" >1</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col9" class="data row1 col9" >2</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col10" class="data row1 col10" >3</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col11" class="data row1 col11" >Male</td>
#                         <td id="T_4f9c330a_8983_11ea_9824_50e08586bf81row1_col12" class="data row1 col12"

# %% [markdown]
# Useful functions throughout this study

# %%
def Correlation_Plot (Df,Fig_Size):
    Correlation_Matrix = Df.corr()
    mask = np.zeros_like(Correlation_Matrix)
    mask[np.triu_indices_from(mask)] = True
    for i in range(len(mask)):
        mask[i,i]=0
    Fig, ax = plt.subplots(figsize=(Fig_Size,Fig_Size))
    sns.heatmap(Correlation_Matrix, ax=ax, mask=mask, annot=True, square=True, 
                cmap =sns.color_palette("RdYlGn", n_colors=Correlation_Matrix.shape[1]),
                linewidths = 0.2, vmin=0, vmax=1, cbar_kws={"shrink": .5})
    bottom, top = ax.get_ylim()

def Search_List(Inp, MyList):
    ''' Search for specific value (Inp) in the column list '''
    Out=list()
    for i in MyList:
        if i.find(Inp) != -1:
            Out.append(i)
    return Out

# %% [markdown]
# # Problem Description
#
# In the dataset, **Attrition** represents whether an employee is churned or not. We would like to create a predictive model that predicts this feature.

# %% [markdown]
# # Modeling

# %% [markdown]
# We need to convert categorical data to numeric data.

# %%
def dtypes_group(Inp):
    Temp = Inp.dtypes.to_frame(name='Data Type').sort_values(by=['Data Type'])
    Out = pd.DataFrame(index =Temp['Data Type'].unique(), columns = ['Columns'])
    for c in Temp['Data Type'].unique():
        Out.loc[Out.index == c, 'Columns'] = [Temp.loc[Temp['Data Type'] == c].index.tolist()]
    return Out
dtypes = dtypes_group(Data)
display(dtypes)
# Out:
#                                                   Columns
# int64   [Age, YearsInCurrentRole, YearsAtCompany, Work...
# object  [Over18, JobRole, EducationField, Gender, Depa...

# %% [markdown]
# We can use **[LabelEncoder](#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)** for converting categorical to numeric using. Therefore,

# %%
df = Data.copy()
Columns = dtypes.loc[dtypes.index == 'object'].values[0,0]
N = len(Columns)
# Progressbar
Counter = 0
Progress_Bar = progressbar.ProgressBar(maxval= N, widgets=[progressbar.Bar('=', '|', '|'), progressbar.Percentage()])

#--------------- the loop ----------------------
Progress_Bar.start()
for i in range(N):
    le = preprocessing.LabelEncoder()
    le.fit(list(df[Columns[i]]))
    df[Columns[i]] = le.transform(df[Columns[i]])
    del le
    Progress_Bar.update(Counter)
    Counter+=1
Progress_Bar.finish()
#--------------- End of the loop ---------------

# Finally, converting values of df back to integers.
df = df.astype(int)

display(dtypes_group(df))
# Out:
# |=========================================================================|100%
#                                                  Columns
# int32  [Age, MonthlyRate, NumCompaniesWorked, Over18,...

# %% [markdown]
# ## Correlation

# %% [markdown]
# Furthemore, let's look at the variance of our dataset features.

# %%
Target = 'Attrition'
display(df.drop(columns = [Target, 'EmployeeNumber']).var().sort_values(ascending = False).to_frame(name= 'Variance')\
        .style.background_gradient(cmap='OrRd').set_precision(2))
# Out:
# <style  type="text/css" >
#     #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row0_col0 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row1_col0 {
#             background-color:  #fda56f;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row2_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row3_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row4_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row5_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row6_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row7_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row8_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row9_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row10_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row11_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row12_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row13_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row14_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row15_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row16_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row17_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row18_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row19_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row20_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row21_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row22_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row23_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row24_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row25_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row26_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row27_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row28_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row29_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row30_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row31_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row32_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }</style><table id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Variance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row0" class="row_heading level0 row0" >MonthlyRate</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row0_col0" class="data row0 col0" >50662878.17</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row1" class="row_heading level0 row1" >MonthlyIncome</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row1_col0" class="data row1 col0" >22164857.07</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row2" class="row_heading level0 row2" >DailyRate</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row2_col0" class="data row2 col0" >162819.59</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row3" class="row_heading level0 row3" >HourlyRate</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row3_col0" class="data row3 col0" >413.29</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row4" class="row_heading level0 row4" >Age</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row4_col0" class="data row4 col0" >83.46</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row5" class="row_heading level0 row5" >DistanceFromHome</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row5_col0" class="data row5 col0" >65.72</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row6" class="row_heading level0 row6" >TotalWorkingYears</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row6_col0" class="data row6 col0" >60.54</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row7" class="row_heading level0 row7" >YearsAtCompany</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row7_col0" class="data row7 col0" >37.53</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row8" class="row_heading level0 row8" >PercentSalaryHike</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row8_col0" class="data row8 col0" >13.40</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row9" class="row_heading level0 row9" >YearsInCurrentRole</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row9_col0" class="data row9 col0" >13.13</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row10" class="row_heading level0 row10" >YearsWithCurrManager</th>
#                         <td id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81row10_col0" class="data row10 col0" >12.73</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa6d6c6_8983_11ea_80e8_50e08586bf81level0_row11" class="row_heading level0 row11" >YearsSinceLastPromotion</th>
#                         <

# %% [markdown]
# Furthermore, we would like to standardize features by removing the mean and scaling to unit **variance**. In this [article](https://hatefdastour.github.io/portfolio/statistical_modeling/Pima_Indians_Diabetes_Data_Classification.html), we demonstrated the benefits of scaling data using [**StandardScaler()**](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html).

# %%
Temp = df.columns.tolist()
Temp = list(set(Temp) - set([Target,'EmployeeNumber']))

scaler = preprocessing.StandardScaler()
df[Temp] = scaler.fit_transform(df[Temp])
Temp = df[Temp].var().sort_values(ascending = False).to_frame(name= 'Variance')    
display(Temp.style.background_gradient(cmap=sns.light_palette("green", as_cmap=True)).set_precision(2))
# Out:
# <style  type="text/css" >
#     #T_4fac1286_8983_11ea_a6c8_50e08586bf81row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row5_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row6_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row7_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row8_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row9_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row10_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row11_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row12_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row13_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row14_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row15_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row16_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row17_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row18_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row19_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row20_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row21_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row22_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row23_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row24_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row25_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row26_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row27_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row28_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row29_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row30_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row31_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4fac1286_8983_11ea_a6c8_50e08586bf81row32_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_4fac1286_8983_11ea_a6c8_50e08586bf81" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Variance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row0" class="row_heading level0 row0" >OverTime</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row0_col0" class="data row0 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row1" class="row_heading level0 row1" >YearsInCurrentRole</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row1_col0" class="data row1 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row2" class="row_heading level0 row2" >Gender</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row2_col0" class="data row2 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row3" class="row_heading level0 row3" >YearsWithCurrManager</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row3_col0" class="data row3 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row4" class="row_heading level0 row4" >Education</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row4_col0" class="data row4 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row5" class="row_heading level0 row5" >RelationshipSatisfaction</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row5_col0" class="data row5 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row6" class="row_heading level0 row6" >EducationField</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row6_col0" class="data row6 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row7" class="row_heading level0 row7" >TotalWorkingYears</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row7_col0" class="data row7 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row8" class="row_heading level0 row8" >Age</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row8_col0" class="data row8 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row9" class="row_heading level0 row9" >JobRole</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row9_col0" class="data row9 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row10" class="row_heading level0 row10" >JobLevel</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row10_col0" class="data row10 col0" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4fac1286_8983_11ea_a6c8_50e08586bf81level0_row11" class="row_heading level0 row11" >MonthlyRate</th>
#                         <td id="T_4fac1286_8983_11ea_a6c8_50e08586bf81row11_col

# %% [markdown]
# Therefore, we can drop columns that have variance zero.

# %%
display(Temp[Temp.Variance == 0].index.tolist())
df.drop(columns = Temp[Temp.Variance == 0].index.tolist(), inplace = True)
# Out:
# ['EmployeeCount', 'StandardHours', 'Over18']

# %%
def Correlation_Plot (Df,Fig_Size):
    Correlation_Matrix = Df.corr().round(2)
    mask = np.zeros_like(Correlation_Matrix)
    mask[np.triu_indices_from(mask)] = True
    for i in range(len(mask)):
        mask[i,i]=0
    Fig, ax = plt.subplots(figsize=(Fig_Size,Fig_Size))
    sns.heatmap(Correlation_Matrix, ax=ax, mask=mask, annot=True, square=True, 
                cmap =sns.color_palette("Greens", n_colors=10), linewidths = 0.2, vmin=0, vmax=1, cbar_kws={"shrink": .6})

Correlation_Plot (df.drop(columns = ['EmployeeNumber']), 16)

# %% [markdown]
# ## Training and testing sets

# %% [markdown]
# We also don't need **EmployeeNumber** for this part of our study. Hence,

# %%
Temp = df.drop(columns = ['EmployeeNumber'])
X = Temp.drop(columns = Target)
y = Temp[Target]
del Temp

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
pd.DataFrame(data={'Set':['X_train','X_test','y_train','y_test'],
               'Shape':[X_train.shape, X_test.shape, y_train.shape, y_test.shape]}).set_index('Set').T
# Out:
# Set       X_train     X_test  y_train  y_test
# Shape  (1029, 30)  (441, 30)  (1029,)  (441,)

# %% [markdown]
# ## Classifiers

# %% [markdown]
# For the next part, we use ROC (receiver operating characteristic curve) AUC (Area Under the ROC Curve) mean and standard deviations for demonstrating a classification model (See more [here](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)).

# %%
classifiers = {'Decision Tree Regression': DecisionTreeRegressor(),
               'Logistic Regression': LogisticRegression(solver='liblinear', random_state=10, class_weight='balanced'),
               'Random Forest Classifier': RandomForestClassifier(n_estimators=100, random_state=10),
               'Decision Tree Classifier': DecisionTreeClassifier(random_state=10),
               'Gaussian NB': GaussianNB()}

# Creating a Table
Results = pd.DataFrame(columns = ['Algorithm', 'ROC AUC Mean', 'ROC AUC STD', 'Accuracy Mean', 'Accuracy STD'])
Mtds = list(classifiers.keys())
kfold = KFold(n_splits=20, random_state=10)

# Start ------------------------------------------------------------------
Progress_Bar = progressbar.ProgressBar(maxval=len(Mtds),
                                       widgets=[progressbar.Bar('=', '|', '|'), progressbar.Percentage()])
Progress_Bar.start()

for i in range(len(Mtds)):
    model_name = Mtds[i]
    model = classifiers[model_name]
    Temp = cross_val_score(model, X_train, y_train, cv=kfold, scoring='accuracy')
    Temp1 = cross_val_score(model, X_train, y_train, cv=kfold, scoring='roc_auc')
    Results.loc[i] = [model_name, round(Temp1.mean()*100, 2), round(Temp1.std()*100, 2),
                         round(Temp.mean()*100, 2), round(Temp.std()*100, 2)]
    Progress_Bar.update(i)
Progress_Bar.finish()
# End ------------------------------------------------------------------
del i, model, model_name, Temp, Temp1
Results = Results.sort_values(by=['ROC AUC Mean'], ascending=False)
display(Results.style.hide_index().background_gradient(cmap='Greens', subset=['ROC AUC Mean'] ).set_precision(2))
# Out:
# |=========================================================================|100%
# <style  type="text/css" >
#     #T_55058702_8983_11ea_99c6_50e08586bf81row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_55058702_8983_11ea_99c6_50e08586bf81row1_col1 {
#             background-color:  #004e1f;
#             color:  #f1f1f1;
#         }    #T_55058702_8983_11ea_99c6_50e08586bf81row2_col1 {
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }    #T_55058702_8983_11ea_99c6_50e08586bf81row3_col1 {
#             background-color:  #f3faf0;
#             color:  #000000;
#         }    #T_55058702_8983_11ea_99c6_50e08586bf81row4_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_55058702_8983_11ea_99c6_50e08586bf81" ><thead>    <tr>        <th class="col_heading level0 col0" >Algorithm</th>        <th class="col_heading level0 col1" >ROC AUC Mean</th>        <th class="col_heading level0 col2" >ROC AUC STD</th>        <th class="col_heading level0 col3" >Accuracy Mean</th>        <th class="col_heading level0 col4" >Accuracy STD</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_55058702_8983_11ea_99c6_50e08586bf81row0_col0" class="data row0 col0" >Logistic Regression</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row0_col1" class="data row0 col1" >81.34</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row0_col2" class="data row0 col2" >7.13</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row0_col3" class="data row0 col3" >75.40</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row0_col4" class="data row0 col4" >5.22</td>
#             </tr>
#             <tr>
#                                 <td id="T_55058702_8983_11ea_99c6_50e08586bf81row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row1_col1" class="data row1 col1" >80.67</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row1_col2" class="data row1 col2" >8.31</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row1_col3" class="data row1 col3" >85.31</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row1_col4" class="data row1 col4" >5.29</td>
#             </tr>
#             <tr>
#                                 <td id="T_55058702_8983_11ea_99c6_50e08586bf81row2_col0" class="data row2 col0" >Gaussian NB</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row2_col1" class="data row2 col1" >77.55</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row2_col2" class="data row2 col2" >9.33</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row2_col3" class="data row2 col3" >75.97</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row2_col4" class="data row2 col4" >6.94</td>
#             </tr>
#             <tr>
#                                 <td id="T_55058702_8983_11ea_99c6_50e08586bf81row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row3_col1" class="data row3 col1" >60.57</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row3_col2" class="data row3 col2" >7.44</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row3_col3" class="data row3 col3" >75.90</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row3_col4" class="data row3 col4" >4.71</td>
#             </tr>
#             <tr>
#                                 <td id="T_55058702_8983_11ea_99c6_50e08586bf81row4_col0" class="data row4 col0" >Decision Tree Regression</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row4_col1" class="data row4 col1" >59.98</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row4_col2" class="data row4 col2" >9.34</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row4_col3" class="data row4 col3" >75.90</td>
#                         <td id="T_55058702_8983_11ea_99c6_50e08586bf81row4_col4" class="data row4 col4" >4.21</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Final Model

# %% [markdown]
# Here, we create a stack of estimators to improve the accuracy of our predictions.

# %%
Temp = Results.loc[Results['ROC AUC Mean'] >= 70, 'Algorithm'].tolist()
Top = [(i, classifiers[i]) for i in Temp]
stacked = StackingClassifier(estimators = Top, final_estimator= classifiers[Temp[0]])
_ = stacked.fit(X_train, y_train)

Temp = cross_val_score(stacked, X_train, y_train, cv=kfold, scoring='accuracy')
Temp1 = cross_val_score(stacked, X_train, y_train, cv=kfold, scoring='roc_auc')
Results.loc[-1] = ['Stacked', round(Temp1.mean()*100, 2), round(Temp1.std()*100, 2), round(Temp.mean()*100, 2),
                   round(Temp.std()*100, 2)]
del Temp, Temp1
Results = Results.sort_values(by=['ROC AUC Mean'], ascending=False)
display(Results.style.hide_index().background_gradient(cmap='Greens', subset=['ROC AUC Mean'] ).set_precision(2))
# Out:
# <style  type="text/css" >
#     #T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row1_col1 {
#             background-color:  #005221;
#             color:  #f1f1f1;
#         }    #T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row2_col1 {
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }    #T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row3_col1 {
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }    #T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row4_col1 {
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }    #T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row5_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81" ><thead>    <tr>        <th class="col_heading level0 col0" >Algorithm</th>        <th class="col_heading level0 col1" >ROC AUC Mean</th>        <th class="col_heading level0 col2" >ROC AUC STD</th>        <th class="col_heading level0 col3" >Accuracy Mean</th>        <th class="col_heading level0 col4" >Accuracy STD</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row0_col0" class="data row0 col0" >Stacked</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row0_col1" class="data row0 col1" >82.30</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row0_col2" class="data row0 col2" >7.77</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row0_col3" class="data row0 col3" >76.47</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row0_col4" class="data row0 col4" >3.44</td>
#             </tr>
#             <tr>
#                                 <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row1_col0" class="data row1 col0" >Logistic Regression</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row1_col1" class="data row1 col1" >81.34</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row1_col2" class="data row1 col2" >7.13</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row1_col3" class="data row1 col3" >75.40</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row1_col4" class="data row1 col4" >5.22</td>
#             </tr>
#             <tr>
#                                 <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row2_col1" class="data row2 col1" >80.67</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row2_col2" class="data row2 col2" >8.31</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row2_col3" class="data row2 col3" >85.31</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row2_col4" class="data row2 col4" >5.29</td>
#             </tr>
#             <tr>
#                                 <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row3_col0" class="data row3 col0" >Gaussian NB</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row3_col1" class="data row3 col1" >77.55</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row3_col2" class="data row3 col2" >9.33</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row3_col3" class="data row3 col3" >75.97</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row3_col4" class="data row3 col4" >6.94</td>
#             </tr>
#             <tr>
#                                 <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row4_col1" class="data row4 col1" >60.57</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row4_col2" class="data row4 col2" >7.44</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row4_col3" class="data row4 col3" >75.90</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row4_col4" class="data row4 col4" >4.71</td>
#             </tr>
#             <tr>
#                                 <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row5_col0" class="data row5 col0" >Decision Tree Regression</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row5_col1" class="data row5 col1" >59.98</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row5_col2" class="data row5 col2" >9.34</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row5_col3" class="data row5 col3" >75.90</td>
#                         <td id="T_6c92c8a4_8983_11ea_a1f4_50e08586bf81row5_col4" class="data row5 col4" >4.21</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Confusion Matrix

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
_ = plot_confusion_matrix(stacked, X_test, y_test, display_labels= ['Not Churned','Churned'],
                      cmap= "Greens", normalize= 'true', ax = ax)
_ = ax.set_title('Normalized Confusion Matrix')

# %% [markdown]
# ## Predictions

# %%
def Prediction(Inp, Model = stacked):
    Temp = df[df.EmployeeNumber==Inp]
    Temp = Temp.drop(columns = ['EmployeeNumber', 'Attrition'])
    Out = Model.predict(Temp)
    if Out == 1:
        Out ='Yes'
    else:
        Out = 'No'
    return Out
def Attrition_fun(en):
    print('Employee Number %i, Churn: %s' % (en, Prediction(en)))

# %% [markdown]
# For example, the **Attrition** value for the following two employees will be

# %%
Attrition_fun(997)
Attrition_fun(120)
# Out:
# Employee Number 997, Churn: No
# Employee Number 120, Churn: Yes

# %% [markdown]
# ***
